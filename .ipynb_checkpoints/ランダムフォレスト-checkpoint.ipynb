# %%
import pandas as pd
import pandas_profiling
import os
import pickle
import gc
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
import lightgbm as lgb

from sklearn.ensemble import RandomForestClassifier

#データ読み込み
train = pd.read_csv("data_EDA/train.csv")
test = pd.read_csv("data_EDA/test.csv")

# %%
train.head()
# Out:
#    index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0    200            9      125             74              0        0
# 1   3832            4      109             80              0        0
# 2   4927            4       88             78             39        0
# 3   4088            9      125             74              0        0
# 4   3644            5      107             78             44      284
#
#          BMI  DiabetesPedigreeFunction  Age  Outcome  BloodPressure_0  \
# 0  28.536910                  0.444902   45      1.0             74.0
# 1  28.047673                  0.238243   22      0.0             80.0
# 2  52.371341                  0.279471   26      0.0             78.0
# 3  40.062688                  0.203922   45      0.0             74.0
# 4  52.935068                  0.284959   45      1.0             78.0
#
#    SkinThickness_0  Insulin_0  SkinThickness_na  BloodPressure_na  Insulin_na  \
# 0              NaN        NaN                 1                 0           1
# 1              NaN        NaN                 1                 0           1
# 2             39.0        NaN                 0                 0           1
# 3              NaN        NaN                 1                 0           1
# 4             44.0      284.0                 0                 0           0
#
#    SkinThickness_mean  BloodPressure_mean  Insulin_mean  Pregnancies_bin
# 0              26.875                74.0    135.636364               10
# 1              26.875                80.0    135.636364                6
# 2              39.000                78.0    135.636364                6
# 3              26.875                74.0    135.636364               10
# 4              44.000                78.0    284.000000                6

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     3000 non-null   int64
#  1   Pregnancies               3000 non-null   int64
#  2   Glucose                   3000 non-null   int64
#  3   BloodPressure             3000 non-null   int64
#  4   SkinThickness             3000 non-null   int64
#  5   Insulin                   3000 non-null   int64
#  6   BMI                       3000 non-null   float64
#  7   DiabetesPedigreeFunction  3000 non-null   float64
#  8   Age                       3000 non-null   int64
#  9   Outcome                   3000 non-null   float64
#  10  BloodPressure_0           2887 non-null   float64
#  11  SkinThickness_0           1234 non-null   float64
#  12  Insulin_0                 256 non-null    float64
#  13  SkinThickness_na          3000 non-null   int64
#  14  BloodPressure_na          3000 non-null   int64
#  15  Insulin_na                3000 non-null   int64
#  16  SkinThickness_mean        3000 non-null   float64
#  17  BloodPressure_mean        3000 non-null   float64
#  18  Insulin_mean              3000 non-null   float64
#  19  Pregnancies_bin           3000 non-null   int64
# dtypes: float64(9), int64(11)
# memory usage: 468.9 KB

# %%
train.describe()
# Out:
#              index  Pregnancies      Glucose  BloodPressure  SkinThickness  \
# count  3000.000000  3000.000000  3000.000000    3000.000000    3000.000000
# mean   2492.964667     3.557000   113.733667      68.743667      11.164000
# std    1447.218078     3.032131    20.885612      16.332755      14.351159
# min       0.000000     0.000000    57.000000       0.000000       0.000000
# 25%    1218.750000     1.000000   100.000000      64.000000       0.000000
# 50%    2465.500000     3.000000   111.000000      70.000000       0.000000
# 75%    3750.250000     6.000000   125.000000      78.000000      24.000000
# max    4999.000000    13.000000   196.000000     110.000000      49.000000
#
#            Insulin          BMI  DiabetesPedigreeFunction          Age  \
# count  3000.000000  3000.000000               3000.000000  3000.000000
# mean     11.663333    35.408959                  0.400476    28.932000
# std      45.064090     6.990180                  0.274666     8.469078
# min       0.000000     7.748040                  0.145844    21.000000
# 25%       0.000000    32.301920                  0.230987    22.000000
# 50%       0.000000    33.835873                  0.268674    26.000000
# 75%       0.000000    39.578256                  0.506778    33.000000
# max     579.000000    53.400629                  2.302072    67.000000
#
#            Outcome  BloodPressure_0  SkinThickness_0   Insulin_0  \
# count  3000.000000      2887.000000      1234.000000  256.000000
# mean      0.239000        71.434361        27.141005  136.679688
# std       0.426544         9.215697         8.182799   82.032125
# min       0.000000        46.000000         7.000000   15.000000
# 25%       0.000000        64.000000        19.000000   79.250000
# 50%       0.000000        70.000000        28.000000  126.000000
# 75%       0.000000        78.000000        33.000000  180.000000
# max       1.000000       110.000000        49.000000  579.000000
#
#        SkinThickness_na  BloodPressure_na   Insulin_na  SkinThickness_mean  \
# count       3000.000000       3000.000000  3000.000000         3000.000000
# mean           0.588667          0.037667     0.914667           26.984417
# std            0.492157          0.190421     0.279424            5.248441
# min            0.000000          0.000000     0.000000            7.000000
# 25%            0.000000          0.000000     1.000000           26.875000
# 50%            1.000000          0.000000     1.000000           26.875000
# 75%            1.000000          0.000000     1.000000           26.875000
# max            1.000000          1.000000     1.000000           49.000000
#
#        BloodPressure_mean  Insulin_mean  Pregnancies_bin
# count         3000.000000   3000.000000      3000.000000
# mean            71.433414    135.725394         5.594000
# std              9.040411     23.922032         2.857951
# min             46.000000     15.000000         3.000000
# 25%             64.000000    135.636364         3.000000
# 50%             71.409223    135.636364         6.000000
# 75%             78.000000    135.636364        10.000000
# max            110.000000    579.000000        10.000000

# %%
# まずは少ない特徴量から検討していく
X_train = train[['DiabetesPedigreeFunction',
                 'BMI',
                 'Glucose',
                 'Age',
                 'Pregnancies',
                 'SkinThickness',
                 'Insulin',
                 'BloodPressure',
                 
                 
                
                 
             ]]
id_train = train[['index']]
y_train = train[['Outcome']]


X_test = test[X_train.columns]
id_test = test[id_train.columns]

# %%
X_train.columns
# Out:
# Index(['DiabetesPedigreeFunction', 'BMI', 'Glucose', 'Age', 'Pregnancies',
#        'SkinThickness', 'Insulin', 'BloodPressure'],
#       dtype='object')

# %%
print(X_train.shape, y_train.shape, id_train.shape)
# Out:
# (3000, 8) (3000, 1) (3000, 1)

# %% [markdown]
# ベースライン評価のため一部データを分ける。
#
# 残りのデータでvalidationしてその条件・目的変数・validation方法・評価指標を仮定し評価する。
#
# 上記3項目を明確にすることをベースラインの決定とする。
#
# validationした後にベースライン評価のためのデータで評価しベースラインを検証する。
#
# validation時とベースライン検証時の結果の傾向に大きな差が無ければベースラインの3項目は問題ないと判断する。
#
# ベースラインが決定すると、その後EDAやモデル改善後はvalidationのみを行い進めていく。
# （変更点や結果を記録）

# %% [markdown]
# ## validation方法（ベースライン作成へ）

# %% [markdown]
# clf = RandomForestClassifier(random_state=1234)
# clf.fit(X_train, y_train)
# print("score=", clf.score(X_test, y_test))

# %%
random_state = 123
params = {'random_state': random_state,
          'criterion': 'gini',

    }

#https://qiita.com/FujiedaTaro/items/61ded4ea5643a6204317#

# %%
# cvでの評価用
def train_rf(input_x,
              input_y,
              input_id,
              params,
              list_nfold=[0,1,2,3,4],
              n_splits=5,
              random_state=123
            ):
    train_oof = np.zeros(len(input_x))
    # foldごとの推論値
    metrics = []
    imp = pd.DataFrame()
                         
    cv = list(StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state).
              split(input_x, input_y))
    
    for nfold in list_nfold:
        print('-'*20, nfold, '-'*20)
        
        idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
        x_tr, y_tr = input_x.loc[idx_tr, :], input_y.loc[idx_tr, :]
        x_va, y_va = input_x.loc[idx_va, :], input_y.loc[idx_va, :]
        print(x_tr.shape, y_tr.shape)
        print(x_va.shape, y_va.shape)
        print('y_train:{:.3f}, y_tr:{:.3f}, y_va{:.3f}'.
              format(y_train['Outcome'].mean(), y_tr['Outcome'].mean(), y_va['Outcome'].mean(),))

        model = RandomForestClassifier(**params_best)
        model.fit(x_tr,
                  y_tr,
                )
        # モデルの保存
        fname_rf = 'model/rf/model_rf_fold{}.pickle'.format(nfold)
        with open(fname_rf, 'wb')as f:
            pickle.dump(model, f, protocol=4)
            
        # 評価
        y_tr_pred = model.predict_proba(x_tr)[:,1]
        y_va_pred = model.predict_proba(x_va)[:,1]
        metric_tr = accuracy_score(y_tr, np.where(y_tr_pred>=0.5,1,0).astype(int))
        metric_va = accuracy_score(y_va, np.where(y_va_pred>=0.5,1,0).astype(int))
        print('[accuracy] tr: {:.2f}, va: {:2f}'.
             format(metric_tr, metric_va))
        metrics.append([nfold, metric_tr, metric_va])
        
        # oof
        train_oof[idx_va] = y_va_pred
        
        # imp
        _imp = pd.DataFrame({'col':input_x.columns, 'imp':model.feature_importances_,'nfold':nfold})
        imp = pd.concat([imp, _imp], axis=0, ignore_index=False)

    print('-'*20, 'result', '-'*20)
    
    # metrix出力
    metrics = np.array(metrics)
    print(metrics)
    print('[cv] tr: {:.2f}+-{:.2f}, va: {:.2f}'.format(
        metrics[:,1].mean(), metrics[:,1].std(),
        metrics[:,2].mean(), metrics[:,2].std()
    ))
    print('[oof] {:.4f}'.format(
        accuracy_score(input_y, np.where(train_oof>=0.5,1,0))))
    # oof出力  
    train_oof = pd.concat([
        input_id,
        pd.DataFrame({'pred':train_oof})]
        ,axis=1)
    
    # imp出力
    imp = imp.groupby('col')['imp'].agg(['mean', 'std']).reset_index(drop=False)
    imp.columns = ['col', 'imp', 'imp_std']

    print('Done')
    
    return train_oof, imp, metrics

# %%
train_oof, imp, metrics = train_rf(X_train, y_train, id_train, params,list_nfold=[0,1,2,3,4], n_splits=5, random_state=123)
# Out:
# -------------------- 0 --------------------
# (2400, 8) (2400, 1)
# (600, 8) (600, 1)
# y_train:0.239, y_tr:0.239, y_va0.240
# [accuracy] tr: 1.00, va: 0.803333
# -------------------- 1 --------------------
# (2400, 8) (2400, 1)
# (600, 8) (600, 1)
# y_train:0.239, y_tr:0.239, y_va0.240
# [accuracy] tr: 1.00, va: 0.796667
# -------------------- 2 --------------------
# (2400, 8) (2400, 1)
# (600, 8) (600, 1)
# y_train:0.239, y_tr:0.239, y_va0.238
# [accuracy] tr: 1.00, va: 0.790000
# -------------------- 3 --------------------
# (2400, 8) (2400, 1)
# (600, 8) (600, 1)
# y_train:0.239, y_tr:0.239, y_va0.238
# [accuracy] tr: 1.00, va: 0.820000
# -------------------- 4 --------------------
# (2400, 8) (2400, 1)
# (600, 8) (600, 1)
# y_train:0.239, y_tr:0.239, y_va0.238
# [accuracy] tr: 1.00, va: 0.790000
# -------------------- result --------------------
# [[0.         1.         0.80333333]
#  [1.         1.         0.79666667]
#  [2.         1.         0.79      ]
#  [3.         1.         0.82      ]
#  [4.         1.         0.79      ]]
# [cv] tr: 1.00+-0.00, va: 0.80
# [oof] 0.8000
# Done

# %%
imp.sort_values('imp', ascending=False)
# Out:
#                         col       imp   imp_std
# 1                       BMI  0.225232  0.004196
# 3  DiabetesPedigreeFunction  0.170634  0.003937
# 0                       Age  0.163568  0.008254
# 4                   Glucose  0.138668  0.001537
# 2             BloodPressure  0.107544  0.001310
# 6               Pregnancies  0.102974  0.002789
# 7             SkinThickness  0.065050  0.001282
# 5                   Insulin  0.026330  0.000778

# %%
train_oof
# Out:
#       index      pred
# 0       200  0.482270
# 1      3832  0.074468
# 2      4927  0.468085
# 3      4088  0.641844
# 4      3644  0.858156
# ...     ...       ...
# 2995   4931  0.209220
# 2996   3264  0.053191
# 2997   1653  0.226950
# 2998   2607  0.446809
# 2999   2732  0.007092
#
# [3000 rows x 2 columns]

# %% [markdown]
# ###
#
# 'DiabetesPedigreeFunction', 'BMI', 'Glucose', 'Age', 'Pregnancies',
#        'BloodPressure_na', 'BloodPressure_0', 'SkinThickness', 'Insulin_0' 'Insulin_na'
#
#
# 'SkinThickness_na' or 'SkinThickness'
# ###

# %%
X_train.columns
# Out:
# Index(['DiabetesPedigreeFunction', 'BMI', 'Glucose', 'Age', 'Pregnancies',
#        'SkinThickness', 'Insulin', 'BloodPressure'],
#       dtype='object')

# %% [markdown]
# ## 推論

# %%
def predict_rf(input_x,
                input_id,
                list_nfold=[0,1,2,3,4],
               ):
    pred = np.zeros((len(input_x), len(list_nfold)))
    for nfold in list_nfold:
        print('-'*20, nfold, '-'*20)
        fname_rf = 'model/rf/model_rf_fold{}.pickle'.format(nfold)
        with open(fname_rf, 'rb')as f:
            model = pickle.load(f)
        pred[:,nfold] = model.predict_proba(input_x)[:,1]
        
    pred = pd.concat([
        input_id,
        pd.DataFrame({'pred':pred.mean(axis=1)}),], axis=1)
    
    print('Done')
    
    return pred

# %%
test_pred_proba = predict_rf(X_test,
                    id_test,
                    list_nfold=[0,1,2,3,4],
                   )
# Out:
# -------------------- 0 --------------------
# -------------------- 1 --------------------
# -------------------- 2 --------------------
# -------------------- 3 --------------------
# -------------------- 4 --------------------
# Done

# %%
test_pred_proba[:3]
# Out:
#    index      pred
# 0    398  0.324113
# 1   3833  0.078014
# 2   4836  0.042553

# %%
test_pred = test_pred_proba.copy()  
test_pred['pred']=np.where(test_pred['pred'] < 0.5, 0, 1)
test_pred[:3]
# Out:
#    index  pred
# 0    398     0
# 1   3833     0
# 2   4836     0

# %%
train_oof[:3]
# Out:
#    index      pred
# 0    200  0.482270
# 1   3832  0.074468
# 2   4927  0.468085

# %%
test_pred.to_csv('sub/submission_rf.csv', index=None, header=False,)

# %% [markdown]
# ## アンサンブル用データ

# %%
import pickle
 
with open('ensamble/rf_train.pickle', mode='wb') as fo:
    pickle.dump(train_oof, fo)
    
with open('ensamble/rf_test.pickle', mode='wb') as fo:
    pickle.dump(test_pred_proba, fo)

# %% [markdown]
# ## ベースライン検証

# %% [markdown]
# ### 初めに検討し問題なければ、その後はスキップ可能

# %% [markdown]
# ベースライン（評価指標や検証法、特徴量選択）の評価を行う
#
# ① 検証データの評価値とベースライン評価値のギャップが小さいか確認
#
# ② 後分類の傾向が似ているか確認
#
# ③ 予測値の分布が似ているか確認
#
# 上記3点が問題なければ、ベースラインを決定し、EDAやモデル改善を行う。

# %%
x_tr, x_va2, y_tr, y_va2 = train_test_split(X_train,
                                           y_train,
                                           test_size=0.2,
                                           shuffle=True,
                                           stratify=y_train,
                                           random_state=random_state)
print('検証データ: ',x_tr.shape, y_tr.shape)
print('ベースライン検証データ: ',x_va2.shape, y_va2.shape)

x_tr1, x_va1, y_tr1, y_va1 = train_test_split(x_tr,
                                              y_tr,
                                              test_size=0.2,
                                              shuffle=True,
                                              stratify=y_tr,
                                              random_state=random_state)
print('検証データ(train): ',x_tr1.shape, y_tr1.shape)
print('検証データ(test): ',x_va1.shape, y_va1.shape)
# Out:
# 検証データ:  (2400, 8) (2400, 1)
# ベースライン検証データ:  (600, 8) (600, 1)
# 検証データ(train):  (1920, 8) (1920, 1)
# 検証データ(test):  (480, 8) (480, 1)

# %%
#validation結果
model = RandomForestClassifier(**params_best)
model.fit(x_tr1,
          y_tr1,
         )
# Out:
# RandomForestClassifier(max_depth=46, n_estimators=282)

# %%
#評価指標の差
y_va1_pred = model.predict(x_va1)
y_va2_pred = model.predict(x_va2)
print('[検証データ] acc: {:.4f}'.format(accuracy_score(y_va1, y_va1_pred)))
print('[ベースライン検証データ] acc: {:.4f}'.format(accuracy_score(y_va2, y_va2_pred)))

y_va1_pred_proba = model.predict_proba(x_va1)
y_va2_pred_proba = model.predict_proba(x_va2)
print('[検証データ] auc: {:.4f}'.format(roc_auc_score(y_va1, y_va1_pred_proba[:,1])))
print('[ベースライン検証データ] auc: {:.4f}'.format(roc_auc_score(y_va2, y_va2_pred_proba[:,1])))
# Out:
# [検証データ] acc: 0.7792
# [ベースライン検証データ] acc: 0.7967
# [検証データ] auc: 0.7601
# [ベースライン検証データ] auc: 0.8294

# %%
#後分類の分布
print('検証データ')
print(confusion_matrix(y_va1, y_va1_pred))
print(confusion_matrix(y_va1, y_va1_pred, normalize='all'))

print('ベースライン検証データ')
print(confusion_matrix(y_va2, y_va2_pred))
print(confusion_matrix(y_va2, y_va2_pred, normalize='all'))
# Out:
# 検証データ
# [[346  19]
#  [ 87  28]]
# [[0.72083333 0.03958333]
#  [0.18125    0.05833333]]
# ベースライン検証データ
# [[430  27]
#  [ 95  48]]
# [[0.71666667 0.045     ]
#  [0.15833333 0.08      ]]

# %%
# 予測値の分布
y_va1_pred_prob = model.predict_proba(x_va1)[:,1]
y_va2_pred_prob = model.predict_proba(x_va2)[:,1]

fig = plt.figure(figsize=(10,8))

fig.add_subplot(2,1,1)
plt.title('validation_data')
plt.hist(y_va1_pred_prob[np.array(y_va1).reshape(-1)==1], bins=10, alpha=0.5, label='1')
plt.hist(y_va1_pred_prob[np.array(y_va1).reshape(-1)==0], bins=10, alpha=0.5, label='0')
plt.grid()
plt.legend()

fig.add_subplot(2,1,2)
plt.title('basreline_validation_data')
plt.hist(y_va2_pred_prob[np.array(y_va2).reshape(-1)==1], bins=10, alpha=0.5, label='1')
plt.hist(y_va2_pred_prob[np.array(y_va2).reshape(-1)==0], bins=10, alpha=0.5, label='0')
plt.grid()
plt.legend()

# %% [markdown]
# ## チューニング

# %%
import optuna

# %% [markdown]
#           'min_samples_split': 2,
#           'min_samples_leaf': 1,
#           'verbose': 1,
#           'n_estimators': 10,
#           'max_depth': None,
#           'min_weight_fraction_leaf': 0,
#           'max_features': 'auto',
#           'max_leaf_nodes': None,
#           'min_impurity_decrease': 0,
#           'bootstrap': True,
#           'oob_score': False,
#           'n_jobs': None,
#           'warm_start': False,
#           'class_weight': None

# %%
# 探索しないパラメータ

params_base = {
    'criterion': 'gini',
    'n_jobs':None,
    'random_state': None,
    'max_features': 'auto'
}
random_state=123

def objective(trial):
    # 探索するパラメータ
    params_tuning = {
        'n_estimators': trial.suggest_int('n_estimators',50,500),
        'max_depth': trial.suggest_int('max_depth',1,100),
        # 'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', 'auto', None])
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy'])
        
         }
    params_tuning.update(params_base)
    
    # モデル学習・評価
    list_metrics = []
    cv = list(StratifiedKFold(n_splits=4, shuffle=True, random_state=random_state).split(X_train, y_train))
    for nfold in np.arange(4):
        idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
        x_tr, y_tr = X_train.loc[idx_tr, :], y_train.loc[idx_tr, :]
        x_va, y_va = X_train.loc[idx_va, :], y_train.loc[idx_va, :]
        
        model = RandomForestClassifier(**params_tuning)
        model.fit(x_tr,
                  y_tr,
                 )
        y_va_pred = model.predict_proba(x_va)[:,1]
        metric_va = accuracy_score(y_va, np.where(y_va_pred>0.5, 1, 0))
        list_metrics.append(metric_va)
        
    # 評価値の計算
    metrics = np.mean(list_metrics)
    
    return metrics

# %%
sampler = optuna.samplers.TPESampler(seed=random_state)
study = optuna.create_study(sampler=sampler, direction='maximize')
study.optimize(objective, n_trials=30)
# Out:
# [I 2023-03-17 07:34:16,216] A new study created in memory with name: no-name-f253604a-ad72-4ca3-94d5-f404af568768
# [I 2023-03-17 07:34:20,387] Trial 0 finished with value: 0.7976666666666667 and parameters: {'n_estimators': 364, 'max_depth': 29, 'criterion': 'entropy'}. Best is trial 0 with value: 0.7976666666666667.
# [I 2023-03-17 07:34:24,512] Trial 1 finished with value: 0.792 and parameters: {'n_estimators': 374, 'max_depth': 43, 'criterion': 'gini'}. Best is trial 0 with value: 0.7976666666666667.
# [I 2023-03-17 07:34:27,495] Trial 2 finished with value: 0.798 and parameters: {'n_estimators': 266, 'max_depth': 40, 'criterion': 'entropy'}. Best is trial 2 with value: 0.798.
# [I 2023-03-17 07:34:29,453] Trial 3 finished with value: 0.7913333333333333 and parameters: {'n_estimators': 247, 'max_depth': 6, 'criterion': 'entropy'}. Best is trial 2 with value: 0.798.
# [I 2023-03-17 07:34:30,931] Trial 4 finished with value: 0.7966666666666666 and parameters: {'n_estimators': 132, 'max_depth': 18, 'criterion': 'entropy'}. Best is trial 2 with value: 0.798.
# [I 2023-03-17 07:34:34,683] Trial 5 finished with value: 0.794 and parameters: {'n_estimators': 336, 'max_depth': 85, 'criterion': 'gini'}. Best is trial 2 with value: 0.798.
# [I 2023-03-17 07:34:38,929] Trial 6 finished with value: 0.7956666666666667 and parameters: {'n_estimators': 375, 'max_depth': 33, 'criterion': 'gini'}. Best is trial 2 with value: 0.798.
# [I 2023-03-17 07:34:41,119] Trial 7 finished with value: 0.7916666666666667 and parameters: {'n_estimators': 182, 'max_depth': 64, 'criterion': 'entropy'}. Best is trial 2 with value: 0.798.
# [I 2023-03-17 07:34:44,026] Trial 8 finished with value: 0.7986666666666666 and parameters: {'n_estimators': 244, 'max_depth': 50, 'criterion': 'gini'}. Best is trial 8 with value: 0.7986666666666666.
# [I 2023-03-17 07:34:47,144] Trial 9 finished with value: 0.798 and parameters: {'n_estimators': 242, 'max_depth': 90, 'criterion': 'gini'}. Best is trial 8 with value: 0.7986666666666666.
# [I 2023-03-17 07:34:53,540] Trial 10 finished with value: 0.7963333333333333 and parameters: {'n_estimators': 493, 'max_depth': 63, 'criterion': 'gini'}. Best is trial 8 with value: 0.7986666666666666.
# [I 2023-03-17 07:34:54,372] Trial 11 finished with value: 0.7913333333333334 and parameters: {'n_estimators': 58, 'max_depth': 58, 'criterion': 'entropy'}. Best is trial 8 with value: 0.7986666666666666.
# [I 2023-03-17 07:34:58,300] Trial 12 finished with value: 0.7993333333333333 and parameters: {'n_estimators': 282, 'max_depth': 46, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:00,379] Trial 13 finished with value: 0.7923333333333333 and parameters: {'n_estimators': 171, 'max_depth': 75, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:05,554] Trial 14 finished with value: 0.7963333333333333 and parameters: {'n_estimators': 442, 'max_depth': 51, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:09,158] Trial 15 finished with value: 0.799 and parameters: {'n_estimators': 304, 'max_depth': 21, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:11,044] Trial 16 finished with value: 0.7666666666666666 and parameters: {'n_estimators': 297, 'max_depth': 2, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:14,594] Trial 17 finished with value: 0.7973333333333334 and parameters: {'n_estimators': 308, 'max_depth': 20, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:16,733] Trial 18 finished with value: 0.7976666666666667 and parameters: {'n_estimators': 181, 'max_depth': 19, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:21,622] Trial 19 finished with value: 0.7973333333333333 and parameters: {'n_estimators': 411, 'max_depth': 99, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:22,881] Trial 20 finished with value: 0.7926666666666666 and parameters: {'n_estimators': 100, 'max_depth': 30, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:25,530] Trial 21 finished with value: 0.7983333333333333 and parameters: {'n_estimators': 225, 'max_depth': 52, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:28,922] Trial 22 finished with value: 0.791 and parameters: {'n_estimators': 288, 'max_depth': 39, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:31,842] Trial 23 finished with value: 0.798 and parameters: {'n_estimators': 210, 'max_depth': 12, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:36,153] Trial 24 finished with value: 0.7966666666666666 and parameters: {'n_estimators': 334, 'max_depth': 71, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:40,127] Trial 25 finished with value: 0.7989999999999999 and parameters: {'n_estimators': 321, 'max_depth': 46, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:44,340] Trial 26 finished with value: 0.796 and parameters: {'n_estimators': 330, 'max_depth': 25, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:50,146] Trial 27 finished with value: 0.7943333333333333 and parameters: {'n_estimators': 432, 'max_depth': 43, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:53,894] Trial 28 finished with value: 0.796 and parameters: {'n_estimators': 285, 'max_depth': 33, 'criterion': 'gini'}. Best is trial 12 with value: 0.7993333333333333.
# [I 2023-03-17 07:35:59,464] Trial 29 finished with value: 0.7973333333333333 and parameters: {'n_estimators': 397, 'max_depth': 26, 'criterion': 'entropy'}. Best is trial 12 with value: 0.7993333333333333.

# %%
trial = study.best_trial
print('acc(best)={:.4f}'.format(trial.value))
display(trial.params)
# Out:
# acc(best)=0.7993
# {'n_estimators': 282, 'max_depth': 46, 'criterion': 'gini'}

# %%
params_best = trial.params
params_best.update(params_base)
display(params_best)
# Out:
# {'n_estimators': 282,
#  'max_depth': 46,
#  'criterion': 'gini',
#  'n_jobs': None,
#  'random_state': None,
#  'max_features': 'auto'}
